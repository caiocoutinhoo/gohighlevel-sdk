# %%
from highlevel_sdk.api import endpoints
import dotenv
import os

# %%
dotenv.load_dotenv()

ghl_token = os.environ.get("GHL_TOKEN")
ghl_location_id = os.environ.get("GHL_LOCATION_ID")

ghl_service = endpoints.GoHighLevelService(token=ghl_token, id_location=ghl_location_id)

# %%
user_data = ghl_service.get_users_dataframe()

# %%
user_data
# Out:
#    deleted                              email                 name  \
# 0    False       michel.inidio@elevads.com.br        Michel Inidio
# 1    False              rafael@elevads.com.br          Rafael Fink
# 2    False  henrique.dornelles@elevads.com.br  Henrique  Dornelles
# 3    False       celso.cardoso@elevads.com.br        Celso Cardoso
# 4    False               pedro@elevads.com.br         Pedro  Mello
# 5    False                 finkrafa@gmail.com         Rafael  Meta
#
#                      id           phone
# 0  1kZMbxYeZJUJC5VwIupK   +554891808675
# 1  5KHSpGYMDKJ3EX5oAKhJ            None
# 2  MsQjaTK31hyLggBDpyt9            None
# 3  SZSH0f0imc8rZjoBQvHR  +5548998241026
# 4  XyuN5bKAlqW0N5ViOrkY            None
# 5  ti7O1bEzw2gZh4NZlqEG            None

# %%
events_calendar = ghl_service.get_calendars_events_dataframe(date='2025-05-12')

# %%
events_calendar
# Out:
#                 event_id                                              title  \
# 0   DbrFGdM0lGVV4Is2s9kn  SR CENTENO -  Consultoria Estratégica Gratuita...
# 1   xaypSqURhHreoUKVNRUI  Brayan  -  Consultoria Estratégica Gratuita | ...
# 2   NR7ZexgrFK78z39aSqPp  Wilfredo  -  Consultoria Estratégica Gratuita ...
# 3   UfCqPCsoURHw393IHYkO  SR CENTENO -  Consultoria Estratégica Gratuita...
# 4   A80GbafJ6hGcrXKU62IM  Luis Indicação Celso   -  Consultoria Estratég...
# 5   GWboCUoLET59TgbikDLZ  PUFF CLEAN.EUA,YOUR CONFORT,OUR CARE-SOFÁ &amp...
# 6   KWYR6ZDsPYgi7qpxACax  Gracielle Carvalho -  Consultoria Estratégica ...
# 7   lHk5E1wmqdVymkc0toDt  🌺Dany Araujo🌺 -  Consultoria Estratégica Gratu...
# 8   axrHzK9j7foFifBJQTfh  Celso -   -  Consultoria Estratégica Gratuita ...
# 9   FVddZEfiqXDQiNFszSaQ  Vania Almeida USA -  Consultoria Estratégica G...
# 10  Q9DvxBx2pxVZLaCClz5M  Dra. Laís Santana -  Consultoria Estratégica G...
# ...

# %%
custom_fields = ghl_service.get_custom_fields_dataframe()

# %%
custom_fields
# Out:
#                       id                                           name  \
# 0   55qahLx1gSeevJC1kT8G                               Você tem sócios?
# 1   KaOMQnbWNCfyiV9cd0k6                            Perfil do Instagram
# 2   oJ0eVK8Gg6LXXxGAnL0b                         Motivo da desinscrição
# 3   vKVJSoGtVKAOscY6ZQjB  What marketing strategy piques your interest?
# 4   mRdfELV6dElXS4hM5N0W                                   Your website
# 5   LeHF42wXqZcx4VSBQKIh                          Seu faturamento anual
# 6   e6Oj3LLUCPxQzUpeHUGe                                        Message
# 7   zJBdIIESMpS2kKWtY9Hs                           Nichos da Construção
# 8   MCiBnqffK6SGO0SJK3Li      Já fez investimentos em anúncios online?
# 9   OQ3N3S5CPDZCDWaOBuX0                            Nome da sua empresa
# 10  Ar5wCxk4dpfMxUDiJ2Rx                      Aonde você nos encontrou?
#
#            data_type                                          field_key  \
# ...

# %%
custom_values = ghl_service.get_custom_values_dataframe()

# %%
custom_values
# Out:
#                      id                                        name  \
# 0  DWms6O3KHPni2hYxSwNG               Facebook API Key de Conversão
# 1  CcpJr8WGwnQNNQxeWy2Q                           Facebook Pixel ID
# 2  0XQVJ6KbQMXAMo2PzpFz                              Mensagem Única
# 3  tOPwTNGrm6EB7HRgWRHR                              Promotion Name
# 4  GCVqeRvtpI9zWqAAR2xc        Marketing - Website Booking Page URL
# 5  C3oP1m8LrI8EVTHXHKJO  Marketing - New Booking Thank You Page URL
# 6  GxUzebQa9eiPN2sMvYBU                                  adset.name
# 7  MgZEJycbsjUwEwjrFmeA                               campaign.name
# 8  vVneLNm7Uo9n9MWEqUeS                                     ad.name
# 9  kT1sngGAANR2hSFM7DBt                                 campaing_id
#
#                                            field_key              value
# 0   {{ custom_values.facebook_api_key_de_converso }}               None
# 1              {{ custom_values.facebook_pixel_id }}               None
# ...

# %%
pipelines = ghl_service.get_pipelines_dataframe()
pipelines
# Out:
#                                 stage_id         stage_name  position  \
# 0   73b2097f-3707-4369-81fa-9498f8de8dfd          Lead Novo         0
# 1   d36061dd-a572-41ab-a1d4-ab6068520237           Hot Lead         1
# 2   0172c281-60d1-4184-ba3e-e43b64e2917e            Follow          2
# 3   39ded7e9-2ec6-49bf-a071-e355bdd65a11   Reunião Agendada         3
# 4   fa07615f-ff3d-440a-b87c-692c10ebec42   Proposta Enviada         4
# ..                                   ...                ...       ...
# 83  a1d71e57-687c-4cfd-8479-0ba338b5b8a5  Lead Evento Paulo         0
# 84  482224ce-9752-43ba-93dc-b403c38fec3c     Lead Evento TM         1
# 85  6739352c-887f-44e1-a63b-db78d959caab          Lead Rafa         2
# 86  7ea18de6-f72c-45f7-ba27-d951507be924  Contato realizado         3
# 87  c20856b3-2dcf-4135-bb3a-9dd2ff549926   Reunião Agendada         4
#
#     show_in_funnel  show_in_pie_chart           pipeline_id  \
# 0             True               True  0NKLkY469mIqMOsN5SN6
# ...

# %%
contacts = ghl_service.get_contacts_dataframe()
contacts
# Out:
#                         id                      contact_name  \
# 0     slIeK0Ch4sMKXRoQF5tq           healthy environment,llc
# 1     iiQGx29xNNAsOtEe95to                         anisleidy
# 2     W4Lg19O1MPlrxcNSXKxa                                ju
# 3     3IGiFnbjYORBJ8dFCs5o                            felipe
# 4     GAKPWjAnK8VFqwXol0rp                     odalys garces
# ...                    ...                               ...
# 5497  nMI2n0RwiqqFXKOun7E3                     magno furtado
# 5498  LbxtpmQNtAWOLacTzbyF                  jocenir teixeira
# 5499  PPFkWy6QcmTGBnlMqyr0        donizete severino da silva
# 5500  dWs87guNCTrBbSw3o0Ue  servio tulio - visto immigration
# 5501  l4jhnl9xK6BXID5keHJz                    fabiana araújo
#
#                             email          phone country  \
# 0                            None   +13467141859      US
# 1                            None   +18135539878      US
# 2                            None   +17753004157      US
# ...

# %%
ghl_service.get_custom_field_values_dataframe()
# Out:
#                contact_id              field_id  \
# 0    QGV3QsMh5zfwM81EHwJP  KaOMQnbWNCfyiV9cd0k6
# 1    QGV3QsMh5zfwM81EHwJP  zJBdIIESMpS2kKWtY9Hs
# 2    k928fr4F9yQ6BHfDvK4G  zJBdIIESMpS2kKWtY9Hs
# 3    eThQJQzcKutJKTp2uZmt  zJBdIIESMpS2kKWtY9Hs
# 4    MVe2rH7oI37RfvwZcXVQ  zJBdIIESMpS2kKWtY9Hs
# ..                    ...                   ...
# 196  HyWkRd0vABt9R7DPp00r  KaOMQnbWNCfyiV9cd0k6
# 197  fqGkeY6qYQFLpsY0QHo8  KaOMQnbWNCfyiV9cd0k6
# 198  zxs9JpBl8zjxuxlC7jh2  KaOMQnbWNCfyiV9cd0k6
# 199  SSlEoYMIpb29i0TUftyo  KaOMQnbWNCfyiV9cd0k6
# 200  Iwyq37uSgQZKb7Szw2Lz  Ar5wCxk4dpfMxUDiJ2Rx
#
#                               field_value
# 0                                    jose
# 1                                Concrete
# 2                              Remodeling
# 3                              Remodeling
# 4                              Remodeling
# ..                                    ...
# 196  https://freeflowairconditioning.com/
# ...

# %%
ghl_service.get_attributions_dataframe()
# Out:
#                                         id        id_association     type  \
# 0     267a7b72-6760-4746-81e7-f8c6324cab2e  UV2Z5lhVSpEHZ6h6F17S  Contact
# 1     06ebeeaf-c248-423e-8b07-a7aaa1277c6d  rK3guDNPgdURvj48DneT  Contact
# 2     27646bb8-5868-47d7-a53c-bcfd270fdaa3  ruj4zr6swxh1XaTlknux  Contact
# 3     c5d59484-3c84-442f-8586-70df9c33eb2f  UdEd3nN0Yf1qJKxhqnDY  Contact
# 4     8b62ccb0-0c9a-4fc1-bc24-0d2db17865a1  3rHNi5UFW8T7IKxKvF0F  Contact
# ...                                    ...                   ...      ...
# 4895  78676f25-92a9-4bc9-962c-7953a2af7696  nMI2n0RwiqqFXKOun7E3  Contact
# 4896  9a692a9f-9cb8-4bec-9400-922d6509113f  LbxtpmQNtAWOLacTzbyF  Contact
# 4897  1342b9d9-fa6b-4a18-8f84-31e0269483d1  LbxtpmQNtAWOLacTzbyF  Contact
# 4898  90bf63c3-59ab-476a-9b78-c43611c290b5  PPFkWy6QcmTGBnlMqyr0  Contact
# 4899  e5f663ae-389a-414b-a2df-fd3106c75e16  PPFkWy6QcmTGBnlMqyr0  Contact
#
#          medium utmSource                               utmCampaign  \
# ...

# %%
opportunities = ghl_service.get_opportunities_dataframe()
opportunities
# Out:
#                 assignedTo             contactId                 createdAt  \
# 0                     None  slIeK0Ch4sMKXRoQF5tq  2025-05-15T17:50:52.065Z
# 1                     None  iiQGx29xNNAsOtEe95to  2025-05-15T17:42:24.117Z
# 2                     None  W4Lg19O1MPlrxcNSXKxa  2025-05-15T16:04:14.249Z
# 3     MsQjaTK31hyLggBDpyt9  3IGiFnbjYORBJ8dFCs5o  2025-05-15T15:38:39.332Z
# 4                     None  GAKPWjAnK8VFqwXol0rp  2025-05-15T15:36:54.910Z
# ...                    ...                   ...                       ...
# 5100                  None  HyWkRd0vABt9R7DPp00r  2024-12-03T03:27:58.118Z
# 5101                  None  fqGkeY6qYQFLpsY0QHo8  2024-12-01T13:24:30.659Z
# 5102                  None  zxs9JpBl8zjxuxlC7jh2  2024-11-30T12:14:02.577Z
# 5103                  None  Iwyq37uSgQZKb7Szw2Lz  2024-07-16T01:57:25.699Z
# 5104                        amqYRvXXO8Y4wZuDtE58  2024-05-24T16:30:15.470Z
#
#                         id         lastStageChangeAt  \
# ...

# %%
ghl_service.get_attributions_dataframe()
# Out:
#                                         id        id_association         type  \
# 0     267a7b72-6760-4746-81e7-f8c6324cab2e  UV2Z5lhVSpEHZ6h6F17S      Contact
# 1     06ebeeaf-c248-423e-8b07-a7aaa1277c6d  rK3guDNPgdURvj48DneT      Contact
# 2     27646bb8-5868-47d7-a53c-bcfd270fdaa3  ruj4zr6swxh1XaTlknux      Contact
# 3     c5d59484-3c84-442f-8586-70df9c33eb2f  UdEd3nN0Yf1qJKxhqnDY      Contact
# 4     8b62ccb0-0c9a-4fc1-bc24-0d2db17865a1  3rHNi5UFW8T7IKxKvF0F      Contact
# ...                                    ...                   ...          ...
# 9562  12bf16e1-6a5a-4284-89e8-ddb5ecb16ee3  WvZ5oRY6Pxs3jR0WMQFN  Opportunity
# 9563  4d02b387-768a-44ed-a427-1fcc9c19c06b  DiMjh9uGqYyxrviMgpRP  Opportunity
# 9564  a8eaf43e-4b7a-4b0e-a6e6-b0836ddd657c  DiMjh9uGqYyxrviMgpRP  Opportunity
# 9565  30d7a0c8-0623-48b9-8efb-0de9262a2caf  0nPJTKVEeAa5jmMXoWJa  Opportunity
# 9566  092b5041-184f-4456-bd01-0310c0718df8  0nPJTKVEeAa5jmMXoWJa  Opportunity
#
# ...
